# %%
import os
import kagglehub

# set cache/download directory to ./data relative to current path
os.environ["KAGGLEHUB_CACHE"] = "./data"

# Download latest version
path = kagglehub.dataset_download("anurag629/chinook-csv-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 143k/143k [00:00<00:00, 578kB/s]
# Extracting files...
# Path to dataset files: ./data/datasets/anurag629/chinook-csv-dataset/versions/1

# %%
SELECT COUNT(CustomerId)
FROM `customer`
